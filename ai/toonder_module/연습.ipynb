# %%
import pandas as pd

df =pd.read_csv("webtoon.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   mastrId           293 non-null    int64
#  1   title             293 non-null    object
#  2   pictrWritrNm      293 non-null    object
#  3   sntncWritrNm      293 non-null    object
#  4   mainGenreCdNm     293 non-null    object
#  5   outline           293 non-null    object
#  6   pltfomCdNm        293 non-null    object
#  7   fnshYn            293 non-null    object
#  8   webtoonPusryYn    293 non-null    object
#  9   imageDownloadUrl  293 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 23.0+ KB

# %%
df['outline'].nunique()
# Out:
# 293

# %%
df = df.dropna()
df = df.drop_duplicates(['imageDownloadUrl'])

# %%
df
# Out:
#         mastrId                   title pictrWritrNm sntncWritrNm  \
# 0    2023157769                    경성빵집          왕보라          왕보라
# 1    2023157768  건방진 끈적한 구멍에, 알 수 없는 벌칙       요시다 고항       요시다 고항
# 2    2023157767             거부해도 넣을 테니까           토시           토시
# 3    2023157766         개가 짖을 때 따라 짖는 법           산양           산양
# 4    2023157765                갓츄! 아일랜드           수자           수자
# ..          ...                     ...          ...          ...
# 288  2023156633                  미식의 세계           미소           미소
# 289  2023156632              무림에서 온 배달부      스튜디오 질풍      스튜디오 질풍
# 290  2023156629              메이지 종속 텅스텐      타츠모토 미오      타츠모토 미오
# 291  2023156627       마피아 보스가 나에게 집착한다!           진나          박효진
# 292  2023156625    레오 님의 집사는 밤일도 맡아드립니다          카사카          카사카
#
#     mainGenreCdNm                                            outline  \
# 0             드라마  1948년, 어머니에게 떠밀려 원치 않는 결혼을 앞둔 18세 소녀, "소앙금" 의 ...
# ...
